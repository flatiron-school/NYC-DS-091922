# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# Convolutional Neural Networks
#
# </p>
# </div>
#
# Data Science Cohort Live NYC July 2022
# <p>Phase 4: Topic 41</p>
# <br>
# <br>
#
# <div align = "right">
# <img src="Images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %%
from PIL import Image, ImageOps
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Convolution Neural Networks (CNNs)
# - An architecture designed for visual pattern recognition
# - Classification/regression on image data

# %% [markdown]
# Why a new architecture?

# %%
dogey = Image.open("Images/dog.jpg")
dogey_grayscale = ImageOps.grayscale(dogey)
display(dogey_grayscale)
# Out:
# <PIL.Image.Image image mode=L size=496x503 at 0x7FEB92777910>

# %%
dg_array = np.array(dogey_grayscale)
dg_array
# Out:
# array([[154, 150, 149, ..., 217, 216, 216],
#        [153, 149, 147, ..., 217, 216, 216],
#        [150, 146, 145, ..., 217, 216, 216],
#        ...,
#        [214, 214, 213, ..., 127, 128, 129],
#        [214, 213, 213, ..., 120, 122, 123],
#        [213, 213, 212, ..., 116, 118, 120]], dtype=uint8)

# %% [markdown]
# Pixel values: high local correlations across columns/rows.

# %% [markdown]
# The problem with standard neural network (aka multilayer perceptron network):
# - let's flatten the doge and inspect features.

# %%
flattened_input = np.ravel(dg_array)
len(flattened_input)
# Out:
# 249488

# %% [markdown]
# All those features go in to MLP:

# %% [markdown]
# <center><img src = "Images/mlp_image.jfif" width =600/></center>
# <center> Number of weights to first layer: huge

# %% [markdown]
# Treats features as independent:
# - Large number of features.
# - Dense connections: large number of weights to tune
# - Weights trying to learn pixel-level correlations

# %% [markdown]
# Not a good idea. Too specific.

# %% [markdown]
# Want to start model at a much higher level of feature abstraction

# %% [markdown]
# #### Building up the convolutional network

# %% [markdown]
# <center><img src = "Images/mlp-convolution-transform.webp" width = 500>

# %% [markdown]
# Cutting connections:
# - not all pixel-pixel interactions relevant.
# - only pass neighboring pixels into given node at next layer.
#
# **Keeps information local**

# %% [markdown]
# <img src = "Images/convolution-mlp-mapping.webp" >

# %% [markdown]
# Full computation corresponds to **convolution**
#
# $$ \begin{bmatrix}
# x_{11} & x_{12} & x_{13} \\
# x_{21} & x_{22} & x_{23} \\
# x_{31} & x_{32} & x_{33}
# \end{bmatrix} *
# \begin{bmatrix}
# w_1 & w_2 \\
# w_3 & w_4
# \end{bmatrix} = \\
# \begin{bmatrix}
# w_1x_{11} + w_2x_{12} + w_3x_{21} + w_4x_{22} & w_1x_{12} + w_2x_{13} + w_3x_{22} + w_4x_{23} \\
# w_1x_{21} + w_2x_{22} + w_3x_{31} + w_4x_{32} & w_1 x_{22} + w_2x_{23} + w_3x_{32} + w_4x_{33}
# \end{bmatrix}$$

# %% [markdown]
# <center><img src = "Images/convolution-mlp-mapping.webp" width = 400 ></center>

# %% [markdown]
# Single node: element-wise multiplication and add them up.
# - A dot product between shared weights and relevant local inputs.

# %% [markdown]
# Convolution in non-flattened output representation:
# - Sliding window with element-wise multiplication/sum
# - Creates new image (2D matrix).

# %% [markdown]
# <center><img src = "Images/convolution.gif" ></center>

# %% [markdown]
# <center><img src = "Images/convolution-mlp-mapping.webp" width = 400 ></center>

# %% [markdown]
# Why applying same weights for the different computations?

# %% [markdown]
# **Weight sharing:**
#
# Idea is that same set of weight patterns useful throughout image:
# - the same kinds of correlations keep showing up across different local regions.

# %% [markdown]
# <img src = "Images/convolution-mlp-mapping.webp" >

# %% [markdown]
# Weights acts as filter:
# - regions with no vertical edge are zero.
# - regions with vertical edge register value.
# - useful in many local areas of image
#
# **Same weight set applied to many local areas**

# %% [markdown]
# <img src = "Images/edge_detector_large.png" >

# %% [markdown]
# Other useful lower-level image features (benefiting from weight sharing):
#
# - Corner/special points
# - region/blob detection

# %% [markdown]
# <img src = "Images/corner_blobs.jpg" >

# %% [markdown]
# Much higher level features:
# - don't need to model pixel level structure

# %% [markdown]
# With colors we have three color dimensions (R/G/B):
# - Filter has three channels (R/G/B)
# - R channel applies a weight set to red intensity pixel values
# - G channel applies another weight set to green, ...

# %% [markdown]
# - Element-wise multiplication/addition channel-wise
# - Add result from all channels together.
#
# <img src = "Images/convwithcolor.png" >

# %% [markdown]
# - Can manually construct sets of filters and feature engineer.
# - But main idea of CNN is to *learn* these filters.
# - Given weight matrix feature engineers: CNN learning image feature extraction.

# %% [markdown]
# Typically, want to learn multiple filters at the same time:
# - Apply each filter/convolve on inputs seperately.
# - Creates stacked output (3D numpy array)

# %% [markdown]
# <img src = "Images/conv_manyfilters_expanded.jpg" width = 200/>

# %% [markdown]
# Multiple filters with colors:
# - Each filter has number of channels
# - Equaling depth of input layer.

# %% [markdown]
# Depth of output is equal to number of filters.

# %% [markdown]
# <img src = "Images/convcolormultifilters.png"  >

# %% [markdown]
# After each convolution operation:
# - apply nonlinear activation to output elementwise.

# %% [markdown]
# <img src = "Images/conv_activation.png" >

# %% [markdown]
# Putting it together: a schematic CNN on a gray-scale image.

# %% [markdown]
# <img src = "Images/conv_manyfilters.png" />

# %% [markdown]
# Haven't seen subsampling/aggregation/pooling yet.

# %% [markdown]
# Putting it together: a schematic CNN on a color image.

# %% [markdown]
# <img src = "Images/colorcnn.png" >

# %% [markdown]
# Haven't seen subsampling/aggregation/pooling yet.

# %% [markdown]
# #### Subsampling/aggregation: pooling layers
#
# - Pooling performs aggregation within window.
# - Stride pooling window across input.
# - Returns reduced representation.
#
#
# *Most common aggregation*: **max pooling**

# %% [markdown]
# <img src = "Images/maxpool.gif" >

# %% [markdown]
# **Intuition behind max pooling**
# - Reducing representation size.
# - Max: selecting on most distinctive feature.
# - Makes insensitive to translation/rotation of features.

# %% [markdown]
# <img src = "Images/maxpool.gif" >

# %% [markdown]
# <center><img src = "Images/translation_invariance_maxpool.jpg" ></center>

# %% [markdown]
# Repeated convolution/pooling:
# - Creates smaller feature maps laterally but more of them.
# - Encodes higher level features and condenses info.

# %% [markdown]
# <img src = "Images/conv_with_pooling_network.jpeg" >

# %% [markdown]
# Final steps involves flattening/connecting to dense fully-connected network:
# - take high level condensed features.
# - learn correct combinations of them.
# - put into sigmoid/softmax

# %% [markdown]
# <img src = "Images/conv_with_pooling_network.jpeg" >

# %% [markdown]
# Apply this to the MNIST digit recognition problem:

# %% [markdown]
# Some old imports:

# %%
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense # creates densely connected layer object
from tensorflow.keras.layers import Flatten # takes 2D input and turns into 1D array

# %% [markdown]
# The new layers

# %%
from tensorflow.keras.layers import Conv2D # convolution layer
from tensorflow.keras.layers import MaxPooling2D # max pooling layer

# %% [markdown]
# Load MNIST

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_labels = to_categorical(train_labels)

# %% [markdown]
# Conv2D takes tensors of shape:
# - (image_height, image_width, color_channels) for each image
# - MNIST has one color channel (grayscale).

# %%
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# %%
train_images.shape
train_labels.shape
# Out:
# (60000, 10)

# %% [markdown]
# Normalize data

# %%
# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255, test_images / 255

# %% [markdown]
# Create the CNN sequential model.

# %%
model = Sequential()
# define 3x3 filter window sizes. Create 32 filters.
model.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(28, 28, 1)))
# max pool in 2x2 window
model.add(MaxPooling2D(pool_size=(2, 2)))
# define 3x3 filter window sizes. Create 64 filters.
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))

# transition to dense fully-connected part of network
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
# Out:
# 2022-11-16 09:32:45.689852: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 09:32:45.690783: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# Let display the architecture of our model so far.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Compile and train the model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_cnn = model.fit(train_images, train_labels, epochs= 20, validation_split = 0.2, batch_size=32, verbose = 2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 - 157s - loss: 0.1709 - accuracy: 0.9476 - val_loss: 0.0629 - val_accuracy: 0.9803
# Epoch 2/20
# 48000/48000 - 139s - loss: 0.0507 - accuracy: 0.9839 - val_loss: 0.0504 - val_accuracy: 0.9852
# Epoch 3/20
# 48000/48000 - 138s - loss: 0.0367 - accuracy: 0.9881 - val_loss: 0.0429 - val_accuracy: 0.9879
# Epoch 4/20
# 48000/48000 - 137s - loss: 0.0284 - accuracy: 0.9912 - val_loss: 0.0384 - val_accuracy: 0.9893
# Epoch 5/20
# 48000/48000 - 137s - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.0447 - val_accuracy: 0.9870
# Epoch 6/20
# 48000/48000 - 133s - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0430 - val_accuracy: 0.9889
# Epoch 7/20
# 48000/48000 - 130s - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.0350 - val_accuracy: 0.9905
# Epoch 8/20
# 48000/48000 - 130s - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0366 - val_accuracy: 0.9910
# Epoch 9/20
# 48000/48000 - 150s - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0509 - val_accuracy: 0.9878
# Epoch 10/20
# 48000/48000 - 142s - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0504 - val_accuracy: 0.9885
# Epoch 11/20
# 48000/48000 - 147s - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0827 - val_accuracy: 0.9822
# Epoch 12/20
# 48000/48000 - 156s - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0477 - val_accuracy: 0.9902
# Epoch 13/20
# 48000/48000 - 154s - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0470 - val_accuracy: 0.9896
# Epoch 14/20
# 48000/48000 - 155s - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0613 - val_accuracy: 0.9888
# Epoch 15/20
# 48000/48000 - 147s - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0650 - val_accuracy: 0.9875
# Epoch 16/20
# 48000/48000 - 159s - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0611 - val_accuracy: 0.9894
# Epoch 17/20
# 48000/48000 - 159s - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0565 - val_accuracy: 0.9907
# Epoch 18/20
# 48000/48000 - 162s - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0619 - val_accuracy: 0.9915
# Epoch 19/20
# 48000/48000 - 158s - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0642 - val_accuracy: 0.9896
# Epoch 20/20
# 48000/48000 - 160s - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0682 - val_accuracy: 0.9894

# %% [markdown]
# #### Evaluate the model

# %%
_, test_acc = model.evaluate(test_images, to_categorical(test_labels), verbose =2)
# Out:
# 10000/1 - 12s - loss: 0.0225 - accuracy: 0.9916

# %%
print(test_acc)
# Out:
# 0.9916

# %%
train_cnn_history = pd.DataFrame(history_cnn.history)
train_cnn_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_cnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_cnn_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Overfitting has occurred: further training is not improving the validation scores in anyway.

# %% [markdown]
# Can we improve this by regularization techniques?
# - typically we add dropout and L2 regularization after the convolutional layers

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

# a new layer that rescales/normalizes the activations after each layer.
# has a weak regularization effect. also allows 

from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation

# %%
model2 = Sequential()
# define 3x3 filter window sizes. Create 32 filters.
model2.add(Conv2D(filters=32,
                        kernel_size=(3, 3),
                        activation='relu',
                        input_shape=(28, 28, 1), kernel_regularizer = l2(5e-4) ))

model2.add(BatchNormalization())
# max pool in 2x2 window
model2.add(MaxPooling2D(pool_size=(2, 2)))
# define 3x3 filter window sizes. Create 64 filters.
model2.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4) ))

model2.add(BatchNormalization())
model2.add(MaxPooling2D((2, 2)))
model2.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer = l2(5e-4)))

model2.add(BatchNormalization())

# transition to dense fully-connected part of network
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(0.2))

model2.add(BatchNormalization())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.25))

model2.add(BatchNormalization())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.25))
model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history_reg = model2.fit(train_images, train_labels, epochs= 50, validation_split = 0.2, batch_size=64)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 177s 4ms/sample - loss: 0.2851 - accuracy: 0.9321 - val_loss: 0.1168 - val_accuracy: 0.9826
# Epoch 2/50
# 48000/48000 [==============================] - 181s 4ms/sample - loss: 0.1295 - accuracy: 0.9782 - val_loss: 0.1077 - val_accuracy: 0.9840
# Epoch 3/50
# 48000/48000 [==============================] - 171s 4ms/sample - loss: 0.1111 - accuracy: 0.9822 - val_loss: 0.0941 - val_accuracy: 0.9868
# Epoch 4/50
# 48000/48000 [==============================] - 171s 4ms/sample - loss: 0.0956 - accuracy: 0.9863 - val_loss: 0.1098 - val_accuracy: 0.9802
# Epoch 5/50
# 48000/48000 [==============================] - 174s 4ms/sample - loss: 0.0852 - accuracy: 0.9880 - val_loss: 0.0920 - val_accuracy: 0.9861
# Epoch 6/50
# 48000/48000 [==============================] - 176s 4ms/sample - loss: 0.0805 - accuracy: 0.9882 - val_loss: 0.0897 - val_accuracy: 0.9855
# Epoch 7/50
# 48000/48000 [==============================] - 173s 4ms/sample - loss: 0.0750 - accuracy: 0.9889 - val_loss: 0.0837 - val_accuracy: 0.9869
# Epoch 8/50
# 48000/48000 [==============================] - 167s 3ms/sample - loss: 0.0747 - accuracy: 0.9896 - val_loss: 0.0807 - val_accuracy: 0.9878
# Epoch 9/50
# 48000/48000 [==============================] - 167s 3ms/sample - loss: 0.0660 - accuracy: 0.9909 - val_loss: 0.0818 - val_accuracy: 0.9872
# Epoch 10/50
# 48000/48000 [==============================] - 160s 3ms/sample - loss: 0.0694 - accuracy: 0.9902 - val_loss: 0.0806 - val_accuracy: 0.9889
# Epoch 11/50
# 48000/48000 [==============================] - 159s 3ms/sample - loss: 0.0656 - accuracy: 0.9912 - val_loss: 0.0692 - val_accuracy: 0.9918
# Epoch 12/50
# 48000/48000 [==============================] - 160s 3ms/sample - loss: 0.0628 - accuracy: 0.9914 - val_loss: 0.0748 - val_accuracy: 0.9893
# Epoch 13/50
# 48000/48000 [==============================] - 159s 3ms/sample - loss: 0.0637 - accuracy: 0.9915 - val_loss: 0.0763 - val_accuracy: 0.9888
# Epoch 14/50
# 48000/48000 [==============================] - 161s 3ms/sample - loss: 0.0587 - accuracy: 0.9924 - val_loss: 0.0687 - val_accuracy: 0.9903
# Epoch 15/50
# 48000/48000 [==============================] - 173s 4ms/sample - loss: 0.0594 - accuracy: 0.9921 - val_loss: 0.0842 - val_accuracy: 0.9878
# Epoch 16/50
# 48000/48000 [==============================] - 170s 4ms/sample - loss: 0.0582 - accuracy: 0.9919 - val_loss: 0.0787 - val_accuracy: 0.9887
# Epoch 17/50
# 48000/48000 [==============================] - 161s 3ms/sample - loss: 0.0554 - accuracy: 0.9931 - val_loss: 0.0813 - val_accuracy: 0.9863
# Epoch 18/50
# 48000/48000 [==============================] - 175s 4ms/sample - loss: 0.0553 - accuracy: 0.9928 - val_loss: 0.0910 - val_accuracy: 0.9855
# Epoch 19/50
# 48000/48000 [==============================] - 163s 3ms/sample - loss: 0.0511 - accuracy: 0.9934 - val_loss: 0.0688 - val_accuracy: 0.9913
# Epoch 20/50
# 48000/48000 [==============================] - 160s 3ms/sample - loss: 0.0547 - accuracy: 0.9925 - val_loss: 0.0767 - val_accuracy: 0.9881
# Epoch 21/50
# 48000/48000 [==============================] - 160s 3ms/sample - loss: 0.0515 - accuracy: 0.9934 - val_loss: 0.0662 - val_accuracy: 0.9908
# Epoch 22/50
# 48000/48000 [==============================] - 161s 3ms/sample - loss: 0.0507 - accuracy: 0.9937 - val_loss: 0.0718 - val_accuracy: 0.9897
# Epoch 23/50
# 48000/48000 [==============================] - 162s 3ms/sample - loss: 0.0494 - accuracy: 0.9937 - val_loss: 0.0779 - val_accuracy: 0.9874
# Epoch 24/50
# 48000/48000 [==============================] - 163s 3ms/sample - loss: 0.0466 - accuracy: 0.9946 - val_loss: 0.0708 - val_accuracy: 0.9894
# Epoch 25/50
# 48000/48000 [==============================] - 164s 3ms/sample - loss: 0.0482 - accuracy: 0.9939 - val_loss: 0.0745 - val_accuracy: 0.9902
# Epoch 26/50
# 48000/48000 [==============================] - 164s 3ms/sample - loss: 0.0473 - accuracy: 0.9944 - val_loss: 0.0808 - val_accuracy: 0.9862
# Epoch 27/50
# 48000/48000 [==============================] - 162s 3ms/sample - loss: 0.0508 - accuracy: 0.9933 - val_loss: 0.0696 - val_accuracy: 0.9904
# Epoch 28/50
# 48000/48000 [==============================] - 160s 3ms/sample - loss: 0.0464 - accuracy: 0.9942 - val_loss: 0.0650 - val_accuracy: 0.9914
# Epoch 29/50
# 48000/48000 [==============================] - 160s 3ms/sample - loss: 0.0444 - accuracy: 0.9945 - val_loss: 0.0771 - val_accuracy: 0.9883
# Epoch 30/50
# 48000/48000 [==============================] - 161s 3ms/sample - loss: 0.0438 - accuracy: 0.9950 - val_loss: 0.0619 - val_accuracy: 0.9918
# Epoch 31/50
# 48000/48000 [==============================] - 161s 3ms/sample - loss: 0.0439 - accuracy: 0.9945 - val_loss: 0.0624 - val_accuracy: 0.9914
# Epoch 32/50
# 48000/48000 [==============================] - 161s 3ms/sample - loss: 0.0451 - accuracy: 0.9944 - val_loss: 0.0626 - val_accuracy: 0.9916
# Epoch 33/50
# 48000/48000 [==============================] - 168s 3ms/sample - loss: 0.0409 - accuracy: 0.9952 - val_loss: 0.0666 - val_accuracy: 0.9921
# Epoch 34/50
# 48000/48000 [==============================] - 180s 4ms/sample - loss: 0.0452 - accuracy: 0.9947 - val_loss: 0.0608 - val_accuracy: 0.9917
# Epoch 35/50
# 48000/48000 [==============================] - 164s 3ms/sample - loss: 0.0437 - accuracy: 0.9945 - val_loss: 0.0643 - val_accuracy: 0.9916
# Epoch 36/50
# 48000/48000 [==============================] - 163s 3ms/sample - loss: 0.0405 - accuracy: 0.9954 - val_loss: 0.0748 - val_accuracy: 0.9902
# Epoch 37/50
# 48000/48000 [==============================] - 162s 3ms/sample - loss: 0.0431 - accuracy: 0.9946 - val_loss: 0.0646 - val_accuracy: 0.9918
# Epoch 38/50
# 48000/48000 [==============================] - 156s 3ms/sample - loss: 0.0404 - accuracy: 0.9953 - val_loss: 0.1448 - val_accuracy: 0.9712
# Epoch 39/50
# 48000/48000 [==============================] - 438s 9ms/sample - loss: 0.0391 - accuracy: 0.9955 - val_loss: 0.0654 - val_accuracy: 0.9915
# Epoch 40/50
# 48000/48000 [==============================] - 1334s 28ms/sample - loss: 0.0413 - accuracy: 0.9952 - val_loss: 0.0753 - val_accuracy: 0.9896
# Epoch 41/50
# 48000/48000 [==============================] - 1241s 26ms/sample - loss: 0.0372 - accuracy: 0.9960 - val_loss: 0.0681 - val_accuracy: 0.9916
# Epoch 42/50
# 48000/48000 [==============================] - 220s 5ms/sample - loss: 0.0379 - accuracy: 0.9956 - val_loss: 0.0729 - val_accuracy: 0.9896
# Epoch 43/50
# 48000/48000 [==============================] - 2329s 49ms/sample - loss: 0.0407 - accuracy: 0.9953 - val_loss: 0.0629 - val_accuracy: 0.9916
# Epoch 44/50
# 48000/48000 [==============================] - 1121s 23ms/sample - loss: 0.0380 - accuracy: 0.9955 - val_loss: 0.0719 - val_accuracy: 0.9902
# Epoch 45/50
# 48000/48000 [==============================] - 607s 13ms/sample - loss: 0.0358 - accuracy: 0.9958 - val_loss: 0.0723 - val_accuracy: 0.9880
# Epoch 46/50
# 48000/48000 [==============================] - 168s 3ms/sample - loss: 0.0381 - accuracy: 0.9954 - val_loss: 0.0584 - val_accuracy: 0.9929
# Epoch 47/50
# 48000/48000 [==============================] - 163s 3ms/sample - loss: 0.0353 - accuracy: 0.9962 - val_loss: 0.0700 - val_accuracy: 0.9887
# Epoch 48/50
# 48000/48000 [==============================] - 175s 4ms/sample - loss: 0.0395 - accuracy: 0.9950 - val_loss: 0.0608 - val_accuracy: 0.9912
# Epoch 49/50
# 48000/48000 [==============================] - 165s 3ms/sample - loss: 0.0343 - accuracy: 0.9962 - val_loss: 0.0780 - val_accuracy: 0.9868
# Epoch 50/50
# 48000/48000 [==============================] - 169s 4ms/sample - loss: 0.0360 - accuracy: 0.9959 - val_loss: 0.0632 - val_accuracy: 0.9919

# %%
_, test2_acc = model2.evaluate(test_images, to_categorical(test_labels))
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
train_regcnn_history = pd.DataFrame(history_reg.history)
train_regcnn_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_regcnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
train_regcnn_history = pd.DataFrame(history_reg.history)
train_regcnn_history.index.name = 'epochs'

col_list = ['accuracy', 'val_accuracy']
train_regcnn_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Changing architecture: simple CNN
# - really high test accuracy.
# - slight overfitting but still good.

# %% [markdown]
# To do much better: many orders of magnitude higher complexity to networks
# - very deep networks required
# - need regularization (L2/dropout)
# - other techniques (batchnorm, skip connections, 1D convolutions etc.)

# %% [markdown]
# Many highly successful pre-trained models exist that can be leveraged:
# - VGG16
# - Resnets
# - Inception Networks

# %% [markdown]
# **Or also just need more data.**
